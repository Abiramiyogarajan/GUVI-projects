# %% [markdown]
# <a href="https://colab.research.google.com/github/Abiramiyogarajan/GUVI-projects/blob/main/studdatabase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
# !pip install pymongo[srv]
# Out:
# ...
#      |████████████████████████████████| 269 kB 5.3 MB/s
# ...

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://abirami:Naveena0688!@cluster0.32lgt.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.studdata

# %%
#collection creation
stud1=db.student1

# %%
images=db.img

# %%
from pymongo import MongoClient
from PIL import Image
import io
im = Image.open("/content/sample_data/1.jpg")
 
image_bytes = io.BytesIO()
im.save(image_bytes, format='JPEG')
 
image = {
   "name":"nature",
   'image': image_bytes.getvalue()
}
 
image_id =images.insert_one(image)

std1={
    "id":input("enter your id for creation use name+std:"),
    "name":input("Enter your name:\n"),
    "Std":input("Enter your standard\n"),
    "Parentname":input("Enter your parent/guardian name:\n"),
    "m1":int(input("Enter your maths marks")),
    "m2":int(input("Enter your maths marks")),
    "m3":int(input("Enter your maths marks"))

   # "DOB":date(input())
}
x=stud1.insert_one(std1)
if x!=None:
  print("record inserted")
else:
  print("not inserted")
#for x in std1.find_one()
#int(x)
# Out:
# enter your id for creation use name+std:figo2
# Enter your name:
# figo
# Enter your standard
# 2
# Enter your parent/guardian name:
# tiyu
# Enter your maths marks56
# Enter your maths marks34
# Enter your maths marks23
# record inserted

# %%
image = images.find_one({"name":"nature"})
 
 
pil_img = Image.open(io.BytesIO(image['image']))
#plt.imshow(pil_img)
#plt.show()
pil_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x750 at 0x7F30B32D9750>
